# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
df = pd.read_csv('Data file.csv')
df
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 0                1      0  21408I70789   272.0   3055.050000   3065.150000
# 1                2      1  76462I70374   712.0  12122.000000  12124.750000
# 2                3      1  17943I70372   535.0   1398.000000   1398.000000
# 3                4      1  55773I70781   241.0     21.228000     21.228000
# 4                5      1  03813I82730   947.0    150.619333    150.619333
# ...            ...    ...          ...     ...           ...           ...
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111667  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228333  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
#         rental30  rental90  last_rech_date_ma  last_rech_date_da  ...  \
# 0         220.13    260.13                2.0                0.0  ...
# 1        3691.26   3691.26               20.0                0.0  ...
# 2         900.13    900.13                3.0                0.0  ...
# 3         159.42    159.42               41.0                0.0  ...
# 4        1098.90   1098.90                4.0                0.0  ...
# ...          ...       ...                ...                ...  ...
# 209588   1089.19   1089.19                1.0                0.0  ...
# 209589   1728.36   1728.36                4.0                0.0  ...
# 209590   5861.83   8893.20                3.0                0.0  ...
# 209591    411.83    984.58                2.0               38.0  ...
# 209592    483.92    631.20               13.0                0.0  ...
#
#         maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 0                   6.0                 0.0          2.0            12
# 1                  12.0                 0.0          1.0            12
# 2                   6.0                 0.0          1.0             6
# 3                   6.0                 0.0          2.0            12
# 4                   6.0                 0.0          7.0            42
# ...                 ...                 ...          ...           ...
# 209588              6.0                 0.0          2.0            12
# 209589              6.0                 0.0          3.0            18
# 209590             12.0                 0.0          6.0            54
# 209591             12.0                 0.0          3.0            24
# 209592             12.0                 0.0          2.0            18
#
#         maxamnt_loans90  medianamnt_loans90  payback30  payback90  pcircle  \
# 0                     6                 0.0  29.000000  29.000000      UPW
# 1                    12                 0.0   0.000000   0.000000      UPW
# 2                     6                 0.0   0.000000   0.000000      UPW
# 3                     6                 0.0   0.000000   0.000000      UPW
# 4                     6                 0.0   2.333333   2.333333      UPW
# ...                 ...                 ...        ...        ...      ...
# 209588                6                 0.0   1.000000   1.000000      UPW
# 209589                6                 0.0   1.000000   1.000000      UPW
# 209590               12                 0.0   4.000000   3.833333      UPW
# 209591               12                 0.0   0.000000  10.500000      UPW
# 209592               12                 0.0   0.000000   0.000000      UPW
#
#              pdate
# 0       2016-07-20
# 1       2016-08-10
# 2       2016-08-19
# 3       2016-06-06
# 4       2016-06-22
# ...            ...
# 209588  2016-06-17
# 209589  2016-06-12
# 209590  2016-07-29
# 209591  2016-07-25
# 209592  2016-07-07
#
# [209593 rows x 37 columns]

# %%
#checking data dimension
df.shape
# Out:
# (209593, 37)

# %%
#display columns of dataframe
df.columns
# Out:
# Index(['Unnamed: 0', 'label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90',
#        'rental30', 'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90', 'pcircle', 'pdate'],
#       dtype='object')

# %%
#drop unnamed column
df.drop('Unnamed: 0',axis=1,inplace=True)
df
# Out:
#         label       msisdn     aon  daily_decr30  daily_decr90  rental30  \
# 0           0  21408I70789   272.0   3055.050000   3065.150000    220.13
# 1           1  76462I70374   712.0  12122.000000  12124.750000   3691.26
# 2           1  17943I70372   535.0   1398.000000   1398.000000    900.13
# 3           1  55773I70781   241.0     21.228000     21.228000    159.42
# 4           1  03813I82730   947.0    150.619333    150.619333   1098.90
# ...       ...          ...     ...           ...           ...       ...
# 209588      1  22758I85348   404.0    151.872333    151.872333   1089.19
# 209589      1  95583I84455  1075.0     36.936000     36.936000   1728.36
# 209590      1  28556I85350  1013.0  11843.111667  11904.350000   5861.83
# 209591      1  59712I82733  1732.0  12488.228333  12574.370000    411.83
# 209592      1  65061I85339  1581.0   4489.362000   4534.820000    483.92
#
#         rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  \
# 0         260.13                2.0                0.0              1539  ...
# 1        3691.26               20.0                0.0              5787  ...
# 2         900.13                3.0                0.0              1539  ...
# 3         159.42               41.0                0.0               947  ...
# 4        1098.90                4.0                0.0              2309  ...
# ...          ...                ...                ...               ...  ...
# 209588   1089.19                1.0                0.0              4048  ...
# 209589   1728.36                4.0                0.0               773  ...
# 209590   8893.20                3.0                0.0              1539  ...
# 209591    984.58                2.0               38.0               773  ...
# 209592    631.20               13.0                0.0              7526  ...
#
#         maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 0                   6.0                 0.0          2.0            12
# 1                  12.0                 0.0          1.0            12
# 2                   6.0                 0.0          1.0             6
# 3                   6.0                 0.0          2.0            12
# 4                   6.0                 0.0          7.0            42
# ...                 ...                 ...          ...           ...
# 209588              6.0                 0.0          2.0            12
# 209589              6.0                 0.0          3.0            18
# 209590             12.0                 0.0          6.0            54
# 209591             12.0                 0.0          3.0            24
# 209592             12.0                 0.0          2.0            18
#
#         maxamnt_loans90  medianamnt_loans90  payback30  payback90  pcircle  \
# 0                     6                 0.0  29.000000  29.000000      UPW
# 1                    12                 0.0   0.000000   0.000000      UPW
# 2                     6                 0.0   0.000000   0.000000      UPW
# 3                     6                 0.0   0.000000   0.000000      UPW
# 4                     6                 0.0   2.333333   2.333333      UPW
# ...                 ...                 ...        ...        ...      ...
# 209588                6                 0.0   1.000000   1.000000      UPW
# 209589                6                 0.0   1.000000   1.000000      UPW
# 209590               12                 0.0   4.000000   3.833333      UPW
# 209591               12                 0.0   0.000000  10.500000      UPW
# 209592               12                 0.0   0.000000   0.000000      UPW
#
#              pdate
# 0       2016-07-20
# 1       2016-08-10
# 2       2016-08-19
# 3       2016-06-06
# 4       2016-06-22
# ...            ...
# 209588  2016-06-17
# 209589  2016-06-12
# 209590  2016-07-29
# 209591  2016-07-25
# 209592  2016-07-07
#
# [209593 rows x 36 columns]

# %%
#display datatypes of columns
df.dtypes
# Out:
# label                     int64
# msisdn                   object
# aon                     float64
# daily_decr30            float64
# daily_decr90            float64
# rental30                float64
# rental90                float64
# last_rech_date_ma       float64
# last_rech_date_da       float64
# last_rech_amt_ma          int64
# cnt_ma_rech30             int64
# fr_ma_rech30            float64
# sumamnt_ma_rech30       float64
# medianamnt_ma_rech30    float64
# medianmarechprebal30    float64
# cnt_ma_rech90             int64
# fr_ma_rech90              int64
# sumamnt_ma_rech90         int64
# medianamnt_ma_rech90    float64
# medianmarechprebal90    float64
# cnt_da_rech30           float64
# fr_da_rech30            float64
# cnt_da_rech90             int64
# fr_da_rech90              int64
# cnt_loans30               int64
# amnt_loans30              int64
# maxamnt_loans30         float64
# medianamnt_loans30      float64
# cnt_loans90             float64
# amnt_loans90              int64
# maxamnt_loans90           int64
# medianamnt_loans90      float64
# payback30               float64
# payback90               float64
# pcircle                  object
# pdate                    object
# dtype: object

# %%
#display information of columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 36 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   label                 209593 non-null  int64
#  1   msisdn                209593 non-null  object
#  2   aon                   209593 non-null  float64
#  3   daily_decr30          209593 non-null  float64
#  4   daily_decr90          209593 non-null  float64
#  5   rental30              209593 non-null  float64
#  6   rental90              209593 non-null  float64
#  7   last_rech_date_ma     209593 non-null  float64
#  8   last_rech_date_da     209593 non-null  float64
#  9   last_rech_amt_ma      209593 non-null  int64
#  10  cnt_ma_rech30         209593 non-null  int64
#  11  fr_ma_rech30          209593 non-null  float64
#  12  sumamnt_ma_rech30     209593 non-null  float64
#  13  medianamnt_ma_rech30  209593 non-null  float64
#  14  medianmarechprebal30  209593 non-null  float64
#  15  cnt_ma_rech90         209593 non-null  int64
#  16  fr_ma_rech90          209593 non-null  int64
#  17  sumamnt_ma_rech90     209593 non-null  int64
#  18  medianamnt_ma_rech90  209593 non-null  float64
#  19  medianmarechprebal90  209593 non-null  float64
#  20  cnt_da_rech30         209593 non-null  float64
#  21  fr_da_rech30          209593 non-null  float64
#  22  cnt_da_rech90         209593 non-null  int64
#  23  fr_da_rech90          209593 non-null  int64
#  24  cnt_loans30           209593 non-null  int64
#  25  amnt_loans30          209593 non-null  int64
#  26  maxamnt_loans30       209593 non-null  float64
#  27  medianamnt_loans30    209593 non-null  float64
#  28  cnt_loans90           209593 non-null  float64
#  29  amnt_loans90          209593 non-null  int64
#  30  maxamnt_loans90       209593 non-null  int64
#  31  medianamnt_loans90    209593 non-null  float64
#  32  payback30             209593 non-null  float64
#  33  payback90             209593 non-null  float64
#  34  pcircle               209593 non-null  object
#  35  pdate                 209593 non-null  object
# dtypes: float64(21), int64(12), object(3)
# memory usage: 57.6+ MB

# %%
#display sum of null values in columns
df.isnull().sum()
# Out:
# label                   0
# msisdn                  0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# pcircle                 0
# pdate                   0
# dtype: int64

# %%
del df['pcircle']

# %%
#display heatmap of null values in columns
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Data Analysis and Visulaization

# %%
#statistical summary.
df.describe().style.background_gradient()
# Out:
# <style type="text/css">
# #T_41be0_row0_col0, #T_41be0_row0_col4, #T_41be0_row0_col5, #T_41be0_row0_col8, #T_41be0_row0_col9, #T_41be0_row0_col12, #T_41be0_row0_col14, #T_41be0_row0_col15, #T_41be0_row0_col17, #T_41be0_row0_col18, #T_41be0_row0_col19, #T_41be0_row0_col21, #T_41be0_row0_col22, #T_41be0_row0_col23, #T_41be0_row0_col24, #T_41be0_row0_col25, #T_41be0_row0_col26, #T_41be0_row0_col27, #T_41be0_row0_col28, #T_41be0_row0_col29, #T_41be0_row0_col30, #T_41be0_row0_col31, #T_41be0_row0_col32, #T_41be0_row7_col1, #T_41be0_row7_col2, #T_41be0_row7_col3, #T_41be0_row7_col6, #T_41be0_row7_col7, #T_41be0_row7_col10, #T_41be0_row7_col11, #T_41be0_row7_col13, #T_41be0_row7_col16, #T_41be0_row7_col20 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_41be0_row0_col1, #T_41be0_row0_col6, #T_41be0_row0_col7, #T_41be0_row0_col10, #T_41be0_row0_col13, #T_41be0_row0_col20 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_41be0_row0_col2 {
#   background-color: #0569a5;
#   color: #f1f1f1;
# }
# #T_41be0_row0_col3 {
#   background-color: #2a88bc;
#   color: #f1f1f1;
# }
# #T_41be0_row0_col11 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_41be0_row0_col16 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_41be0_row1_col0, #T_41be0_row1_col6, #T_41be0_row1_col7, #T_41be0_row1_col9, #T_41be0_row1_col10, #T_41be0_row1_col14, #T_41be0_row1_col15, #T_41be0_row1_col18, #T_41be0_row1_col19, #T_41be0_row1_col20, #T_41be0_row1_col21, #T_41be0_row1_col22, #T_41be0_row1_col23, #T_41be0_row1_col24, #T_41be0_row1_col25, #T_41be0_row1_col26, #T_41be0_row1_col27, #T_41be0_row1_col28, #T_41be0_row1_col29, #T_41be0_row1_col30, #T_41be0_row1_col31, #T_41be0_row1_col32, #T_41be0_row2_col0, #T_41be0_row2_col9, #T_41be0_row2_col14, #T_41be0_row2_col15, #T_41be0_row2_col18, #T_41be0_row2_col21, #T_41be0_row2_col22, #T_41be0_row2_col23, #T_41be0_row2_col24, #T_41be0_row2_col26, #T_41be0_row2_col27, #T_41be0_row2_col28, #T_41be0_row2_col29, #T_41be0_row2_col30, #T_41be0_row2_col31, #T_41be0_row2_col32, #T_41be0_row3_col0, #T_41be0_row3_col1, #T_41be0_row3_col2, #T_41be0_row3_col3, #T_41be0_row3_col4, #T_41be0_row3_col5, #T_41be0_row3_col6, #T_41be0_row3_col7, #T_41be0_row3_col8, #T_41be0_row3_col9, #T_41be0_row3_col10, #T_41be0_row3_col11, #T_41be0_row3_col12, #T_41be0_row3_col13, #T_41be0_row3_col14, #T_41be0_row3_col15, #T_41be0_row3_col16, #T_41be0_row3_col17, #T_41be0_row3_col18, #T_41be0_row3_col19, #T_41be0_row3_col20, #T_41be0_row3_col21, #T_41be0_row3_col22, #T_41be0_row3_col23, #T_41be0_row3_col24, #T_41be0_row3_col25, #T_41be0_row3_col26, #T_41be0_row3_col27, #T_41be0_row3_col28, #T_41be0_row3_col29, #T_41be0_row3_col30, #T_41be0_row3_col31, #T_41be0_row3_col32, #T_41be0_row4_col0, #T_41be0_row4_col1, #T_41be0_row4_col2, #T_41be0_row4_col3, #T_41be0_row4_col6, #T_41be0_row4_col7, #T_41be0_row4_col8, #T_41be0_row4_col9, #T_41be0_row4_col10, #T_41be0_row4_col11, #T_41be0_row4_col12, #T_41be0_row4_col13, #T_41be0_row4_col14, #T_41be0_row4_col15, #T_41be0_row4_col16, #T_41be0_row4_col17, #T_41be0_row4_col18, #T_41be0_row4_col19, #T_41be0_row4_col20, #T_41be0_row4_col21, #T_41be0_row4_col22, #T_41be0_row4_col23, #T_41be0_row4_col24, #T_41be0_row4_col25, #T_41be0_row4_col26, #T_41be0_row4_col27, #T_41be0_row4_col28, #T_41be0_row4_col29, #T_41be0_row4_col30, #T_41be0_row4_col31, #T_41be0_row4_col32, #T_41be0_row5_col0, #T_41be0_row5_col1, #T_41be0_row5_col6, #T_41be0_row5_col7, #T_41be0_row5_col9, #T_41be0_row5_col10, #T_41be0_row5_col13, #T_41be0_row5_col14, #T_41be0_row5_col15, #T_41be0_row5_col18, #T_41be0_row5_col19, #T_41be0_row5_col20, #T_41be0_row5_col21, #T_41be0_row5_col22, #T_41be0_row5_col23, #T_41be0_row5_col24, #T_41be0_row5_col25, #T_41be0_row5_col26, #T_41be0_row5_col27, #T_41be0_row5_col28, #T_41be0_row5_col29, #T_41be0_row5_col30, #T_41be0_row5_col31, #T_41be0_row5_col32, #T_41be0_row6_col0, #T_41be0_row6_col1, #T_41be0_row6_col6, #T_41be0_row6_col7, #T_41be0_row6_col9, #T_41be0_row6_col10, #T_41be0_row6_col13, #T_41be0_row6_col14, #T_41be0_row6_col15, #T_41be0_row6_col18, #T_41be0_row6_col19, #T_41be0_row6_col20, #T_41be0_row6_col21, #T_41be0_row6_col22, #T_41be0_row6_col23, #T_41be0_row6_col24, #T_41be0_row6_col25, #T_41be0_row6_col26, #T_41be0_row6_col27, #T_41be0_row6_col28, #T_41be0_row6_col29, #T_41be0_row6_col30, #T_41be0_row6_col31, #T_41be0_row6_col32, #T_41be0_row7_col0, #T_41be0_row7_col9, #T_41be0_row7_col14, #T_41be0_row7_col15, #T_41be0_row7_col21, #T_41be0_row7_col22, #T_41be0_row7_col23, #T_41be0_row7_col24, #T_41be0_row7_col26, #T_41be0_row7_col28, #T_41be0_row7_col29, #T_41be0_row7_col30, #T_41be0_row7_col31, #T_41be0_row7_col32 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_41be0_row1_col1, #T_41be0_row1_col8, #T_41be0_row1_col11, #T_41be0_row1_col12, #T_41be0_row1_col17, #T_41be0_row2_col8, #T_41be0_row2_col12, #T_41be0_row2_col17, #T_41be0_row6_col8, #T_41be0_row6_col12, #T_41be0_row6_col17 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_41be0_row1_col2, #T_41be0_row2_col19, #T_41be0_row2_col25 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_41be0_row1_col3, #T_41be0_row1_col16, #T_41be0_row2_col11, #T_41be0_row2_col16, #T_41be0_row6_col11, #T_41be0_row6_col16 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_41be0_row1_col4, #T_41be0_row5_col5 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_41be0_row1_col5, #T_41be0_row2_col4 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_41be0_row1_col13, #T_41be0_row5_col2, #T_41be0_row5_col3, #T_41be0_row5_col8, #T_41be0_row5_col11, #T_41be0_row5_col12, #T_41be0_row5_col16, #T_41be0_row5_col17 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_41be0_row2_col1 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_41be0_row2_col2, #T_41be0_row2_col3 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_41be0_row2_col5 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_41be0_row2_col6, #T_41be0_row2_col7, #T_41be0_row2_col10, #T_41be0_row2_col13, #T_41be0_row2_col20 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_41be0_row4_col4 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_41be0_row4_col5, #T_41be0_row5_col4 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_41be0_row6_col2 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_41be0_row6_col3, #T_41be0_row7_col27 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_41be0_row6_col4 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_41be0_row6_col5 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_41be0_row7_col4 {
#   background-color: #03446a;
#   color: #f1f1f1;
# }
# #T_41be0_row7_col5 {
#   background-color: #034369;
#   color: #f1f1f1;
# }
# #T_41be0_row7_col8, #T_41be0_row7_col12, #T_41be0_row7_col17 {
#   background-color: #cccfe5;
#   color: #000000;
# }
# #T_41be0_row7_col18 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_41be0_row7_col19 {
#   background-color: #7dacd1;
#   color: #f1f1f1;
# }
# #T_41be0_row7_col25 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_41be0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_41be0_level0_col0" class="col_heading level0 col0" >label</th>
#       <th id="T_41be0_level0_col1" class="col_heading level0 col1" >aon</th>
#       <th id="T_41be0_level0_col2" class="col_heading level0 col2" >daily_decr30</th>
#       <th id="T_41be0_level0_col3" class="col_heading level0 col3" >daily_decr90</th>
#       <th id="T_41be0_level0_col4" class="col_heading level0 col4" >rental30</th>
#       <th id="T_41be0_level0_col5" class="col_heading level0 col5" >rental90</th>
#       <th id="T_41be0_level0_col6" class="col_heading level0 col6" >last_rech_date_ma</th>
#       <th id="T_41be0_level0_col7" class="col_heading level0 col7" >last_rech_date_da</th>
#       <th id="T_41be0_level0_col8" class="col_heading level0 col8" >last_rech_amt_ma</th>
#       <th id="T_41be0_level0_col9" class="col_heading level0 col9" >cnt_ma_rech30</th>
#       <th id="T_41be0_level0_col10" class="col_heading level0 col10" >fr_ma_rech30</th>
#       <th id="T_41be0_level0_c

# %%
df['payback30'].unique()
# Out:
# array([29.        ,  0.        ,  2.33333333, ..., 56.75      ,
#        64.33333333,  5.61538462])

# %%
df['payback30'].value_counts()
# Out:
# 0.000000     106712
# 2.000000       5601
# 3.000000       5023
# 4.000000       3931
# 2.500000       3518
#               ...
# 4.545455          1
# 48.400000         1
# 3.133333          1
# 1.518519          1
# 5.615385          1
# Name: payback30, Length: 1363, dtype: int64

# %%
#number of values for each quality.
sns.countplot(x='payback30',data=df)
plot = plt.figure(figsize=(10,5))

# %%
#citric acid vs Quality
plot = plt.figure(figsize=(5,5))
sns.barplot(x='payback30',y='medianamnt_loans30', data=df)
# Out:
# <AxesSubplot:xlabel='payback30', ylabel='medianamnt_loans30'>

# %%
sns.scatterplot(x='payback90',y='payback30',data=df)
plt.show()

# %%
df.corr().style.background_gradient()
# Out:
# <style type="text/css">
# #T_bcfda_row0_col0, #T_bcfda_row1_col1, #T_bcfda_row2_col2, #T_bcfda_row3_col3, #T_bcfda_row4_col4, #T_bcfda_row5_col5, #T_bcfda_row6_col6, #T_bcfda_row7_col7, #T_bcfda_row8_col8, #T_bcfda_row9_col9, #T_bcfda_row10_col10, #T_bcfda_row11_col11, #T_bcfda_row12_col12, #T_bcfda_row13_col13, #T_bcfda_row14_col14, #T_bcfda_row15_col15, #T_bcfda_row16_col16, #T_bcfda_row17_col17, #T_bcfda_row18_col18, #T_bcfda_row19_col19, #T_bcfda_row20_col20, #T_bcfda_row21_col21, #T_bcfda_row22_col22, #T_bcfda_row23_col23, #T_bcfda_row24_col24, #T_bcfda_row25_col25, #T_bcfda_row26_col26, #T_bcfda_row27_col27, #T_bcfda_row28_col28, #T_bcfda_row29_col29, #T_bcfda_row30_col30, #T_bcfda_row31_col31, #T_bcfda_row32_col32 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_bcfda_row0_col1, #T_bcfda_row0_col13, #T_bcfda_row0_col20, #T_bcfda_row0_col22, #T_bcfda_row0_col25, #T_bcfda_row1_col0, #T_bcfda_row1_col7, #T_bcfda_row1_col10, #T_bcfda_row1_col25, #T_bcfda_row1_col27, #T_bcfda_row2_col7, #T_bcfda_row2_col10, #T_bcfda_row2_col13, #T_bcfda_row2_col20, #T_bcfda_row2_col25, #T_bcfda_row3_col7, #T_bcfda_row3_col10, #T_bcfda_row3_col20, #T_bcfda_row3_col25, #T_bcfda_row4_col1, #T_bcfda_row4_col6, #T_bcfda_row4_col10, #T_bcfda_row4_col13, #T_bcfda_row4_col19, #T_bcfda_row4_col20, #T_bcfda_row4_col25, #T_bcfda_row5_col1, #T_bcfda_row5_col6, #T_bcfda_row5_col10, #T_bcfda_row5_col13, #T_bcfda_row5_col19, #T_bcfda_row5_col20, #T_bcfda_row5_col25, #T_bcfda_row6_col10, #T_bcfda_row6_col19, #T_bcfda_row6_col20, #T_bcfda_row6_col21, #T_bcfda_row6_col22, #T_bcfda_row6_col25, #T_bcfda_row6_col27, #T_bcfda_row7_col1, #T_bcfda_row7_col19, #T_bcfda_row7_col20, #T_bcfda_row7_col25, #T_bcfda_row7_col27, #T_bcfda_row8_col6, #T_bcfda_row8_col7, #T_bcfda_row8_col13, #T_bcfda_row8_col19, #T_bcfda_row8_col20, #T_bcfda_row8_col25, #T_bcfda_row8_col27, #T_bcfda_row9_col1, #T_bcfda_row9_col15, #T_bcfda_row9_col20, #T_bcfda_row9_col25, #T_bcfda_row10_col1, #T_bcfda_row10_col6, #T_bcfda_row10_col19, #T_bcfda_row10_col20, #T_bcfda_row10_col22, #T_bcfda_row10_col25, #T_bcfda_row11_col7, #T_bcfda_row11_col10, #T_bcfda_row11_col20, #T_bcfda_row12_col6, #T_bcfda_row12_col10, #T_bcfda_row12_col19, #T_bcfda_row12_col20, #T_bcfda_row12_col27, #T_bcfda_row13_col0, #T_bcfda_row13_col19, #T_bcfda_row13_col21, #T_bcfda_row13_col25, #T_bcfda_row14_col1, #T_bcfda_row14_col15, #T_bcfda_row14_col20, #T_bcfda_row14_col25, #T_bcfda_row15_col2, #T_bcfda_row15_col3, #T_bcfda_row15_col4, #T_bcfda_row15_col5, #T_bcfda_row15_col9, #T_bcfda_row15_col10, #T_bcfda_row15_col11, #T_bcfda_row15_col14, #T_bcfda_row15_col16, #T_bcfda_row15_col20, #T_bcfda_row15_col21, #T_bcfda_row15_col22, #T_bcfda_row15_col23, #T_bcfda_row15_col24, #T_bcfda_row15_col27, #T_bcfda_row15_col28, #T_bcfda_row15_col29, #T_bcfda_row16_col7, #T_bcfda_row16_col10, #T_bcfda_row16_col20, #T_bcfda_row16_col25, #T_bcfda_row16_col32, #T_bcfda_row17_col6, #T_bcfda_row17_col7, #T_bcfda_row17_col10, #T_bcfda_row17_col13, #T_bcfda_row17_col19, #T_bcfda_row17_col20, #T_bcfda_row17_col25, #T_bcfda_row17_col27, #T_bcfda_row17_col31, #T_bcfda_row18_col1, #T_bcfda_row18_col6, #T_bcfda_row18_col10, #T_bcfda_row18_col20, #T_bcfda_row18_col27, #T_bcfda_row18_col31, #T_bcfda_row18_col32, #T_bcfda_row19_col6, #T_bcfda_row19_col7, #T_bcfda_row19_col10, #T_bcfda_row19_col13, #T_bcfda_row19_col25, #T_bcfda_row19_col27, #T_bcfda_row20_col6, #T_bcfda_row20_col7, #T_bcfda_row20_col10, #T_bcfda_row20_col25, #T_bcfda_row20_col27, #T_bcfda_row21_col6, #T_bcfda_row21_col7, #T_bcfda_row21_col13, #T_bcfda_row21_col25, #T_bcfda_row22_col0, #T_bcfda_row22_col6, #T_bcfda_row22_col7, #T_bcfda_row22_col10, #T_bcfda_row22_col13, #T_bcfda_row22_col19, #T_bcfda_row22_col25, #T_bcfda_row23_col1, #T_bcfda_row23_col8, #T_bcfda_row23_col12, #T_bcfda_row23_col17, #T_bcfda_row23_col18, #T_bcfda_row23_col20, #T_bcfda_row23_col25, #T_bcfda_row23_col26, #T_bcfda_row23_col30, #T_bcfda_row24_col1, #T_bcfda_row24_col20, #T_bcfda_row24_col25, #T_bcfda_row25_col1, #T_bcfda_row25_col10, #T_bcfda_row25_col13, #T_bcfda_row25_col19, #T_bcfda_row25_col20, #T_bcfda_row26_col7, #T_bcfda_row26_col10, #T_bcfda_row26_col13, #T_bcfda_row26_col19, #T_bcfda_row26_col20, #T_bcfda_row26_col21, #T_bcfda_row26_col22, #T_bcfda_row26_col27, #T_bcfda_row27_col1, #T_bcfda_row27_col6, #T_bcfda_row27_col7, #T_bcfda_row27_col19, #T_bcfda_row27_col20, #T_bcfda_row28_col1, #T_bcfda_row28_col20, #T_bcfda_row28_col25, #T_bcfda_row28_col30, #T_bcfda_row29_col1, #T_bcfda_row29_col6, #T_bcfda_row29_col10, #T_bcfda_row29_col13, #T_bcfda_row29_col19, #T_bcfda_row29_col20, #T_bcfda_row29_col25, #T_bcfda_row30_col4, #T_bcfda_row30_col5, #T_bcfda_row30_col7, #T_bcfda_row30_col10, #T_bcfda_row30_col13, #T_bcfda_row30_col19, #T_bcfda_row30_col20, #T_bcfda_row30_c ...
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_bcfda_row0_col2, #T_bcfda_row0_col3 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_bcfda_row0_col4, #T_bcfda_row1_col30, #T_bcfda_row6_col30, #T_bcfda_row22_col2, #T_bcfda_row24_col31, #T_bcfda_row25_col26, #T_bcfda_row26_col17, #T_bcfda_row29_col15, #T_bcfda_row31_col3 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_bcfda_row0_col5, #T_bcfda_row1_col24, #T_bcfda_row6_col23, #T_bcfda_row7_col23, #T_bcfda_row8_col30, #T_bcfda_row10_col23, #T_bcfda_row13_col23, #T_bcfda_row18_col2, #T_bcfda_row18_col3, #T_bcfda_row19_col23, #T_bcfda_row20_col24, #T_bcfda_row21_col2, #T_bcfda_row25_col23 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_bcfda_row0_col6, #T_bcfda_row0_col7, #T_bcfda_row0_col10, #T_bcfda_row0_col19, #T_bcfda_row1_col6, #T_bcfda_row1_col19, #T_bcfda_row1_col20, #T_bcfda_row1_col21, #T_bcfda_row2_col1, #T_bcfda_row2_col6, #T_bcfda_row2_col19, #T_bcfda_row3_col1, #T_bcfda_row3_col6, #T_bcfda_row3_col13, #T_bcfda_row3_col19, #T_bcfda_row4_col7, #T_bcfda_row4_col27, #T_bcfda_row5_col7, #T_bcfda_row6_col1, #T_bcfda_row6_col7, #T_bcfda_row7_col0, #T_bcfda_row7_col6, #T_bcfda_row7_col10, #T_bcfda_row7_col13, #T_bcfda_row7_col21, #T_bcfda_row7_col22, #T_bcfda_row8_col10, #T_bcfda_row9_col7, #T_bcfda_row9_col10, #T_bcfda_row9_col13, #T_bcfda_row9_col19, #T_bcfda_row10_col0, #T_bcfda_row10_col7, #T_bcfda_row10_col13, #T_bcfda_row10_col27, #T_bcfda_row11_col1, #T_bcfda_row11_col6, #T_bcfda_row11_col13, #T_bcfda_row11_col19, #T_bcfda_row11_col25, #T_bcfda_row12_col7, #T_bcfda_row12_col13, #T_bcfda_row12_col25, #T_bcfda_row13_col1, #T_bcfda_row13_col6, #T_bcfda_row13_col7, #T_bcfda_row13_col10, #T_bcfda_row13_col20, #T_bcfda_row13_col22, #T_bcfda_row13_col27, #T_bcfda_row14_col7, #T_bcfda_row14_col10, #T_bcfda_row14_col13, #T_bcfda_row14_col19, #T_bcfda_row15_col6, #T_bcfda_row15_col7, #T_bcfda_row15_col13, #T_bcfda_row15_col19, #T_bcfda_row15_col25, #T_bcfda_row16_col1, #T_bcfda_row16_col6, #T_bcfda_row16_col13, #T_bcfda_row16_col19, #T_bcfda_row18_col7, #T_bcfda_row18_col13, #T_bcfda_row18_col19, #T_bcfda_row18_col25, #T_bcfda_row19_col1, #T_bcfda_row19_col22, #T_bcfda_row20_col0, #T_bcfda_row20_col1, #T_bcfda_row20_col13, #T_bcfda_row20_col21, #T_bcfda_row21_col1, #T_bcfda_row21_col10, #T_bcfda_row21_col19, #T_bcfda_row21_col20, #T_bcfda_row21_col27, #T_bcfda_row22_col27, #T_bcfda_row23_col6, #T_bcfda_row23_col7, #T_bcfda_row23_col10, #T_bcfda_row23_col13, #T_bcfda_row23_col19, #T_bcfda_row24_col6, #T_bcfda_row24_col7, #T_bcfda_row24_col10, #T_bcfda_row24_col13, #T_bcfda_row24_col19, #T_bcfda_row25_col0, #T_bcfda_row25_col6, #T_bcfda_row25_col7, #T_bcfda_row25_col21, #T_bcfda_row25_col22, #T_bcfda_row25_col27, #T_bcfda_row26_col6, #T_bcfda_row27_col10, #T_bcfda_row27_col13, #T_bcfda_row27_col21, #T_bcfda_row27_col22, #T_bcfda_row27_col25, #T_bcfda_row28_col6, #T_bcfda_row28_col7, #T_bcfda_row28_col10, #T_bcfda_row28_col13, #T_bcfda_row28_col18, #T_bcfda

# %%
corr_mat = df.corr()
plt.figure(figsize=(10,8))
sns.heatmap(corr_mat, annot=True, fmt = '.1f',cmap = 'Blues')
plt.title('Correlation matrix')
plt.show()

# %%
corr_matrix = df.corr().style.background_gradient()
corr_matrix
# Out:
# <style type="text/css">
# #T_7144a_row0_col0, #T_7144a_row1_col1, #T_7144a_row2_col2, #T_7144a_row3_col3, #T_7144a_row4_col4, #T_7144a_row5_col5, #T_7144a_row6_col6, #T_7144a_row7_col7, #T_7144a_row8_col8, #T_7144a_row9_col9, #T_7144a_row10_col10, #T_7144a_row11_col11, #T_7144a_row12_col12, #T_7144a_row13_col13, #T_7144a_row14_col14, #T_7144a_row15_col15, #T_7144a_row16_col16, #T_7144a_row17_col17, #T_7144a_row18_col18, #T_7144a_row19_col19, #T_7144a_row20_col20, #T_7144a_row21_col21, #T_7144a_row22_col22, #T_7144a_row23_col23, #T_7144a_row24_col24, #T_7144a_row25_col25, #T_7144a_row26_col26, #T_7144a_row27_col27, #T_7144a_row28_col28, #T_7144a_row29_col29, #T_7144a_row30_col30, #T_7144a_row31_col31, #T_7144a_row32_col32 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_7144a_row0_col1, #T_7144a_row0_col13, #T_7144a_row0_col20, #T_7144a_row0_col22, #T_7144a_row0_col25, #T_7144a_row1_col0, #T_7144a_row1_col7, #T_7144a_row1_col10, #T_7144a_row1_col25, #T_7144a_row1_col27, #T_7144a_row2_col7, #T_7144a_row2_col10, #T_7144a_row2_col13, #T_7144a_row2_col20, #T_7144a_row2_col25, #T_7144a_row3_col7, #T_7144a_row3_col10, #T_7144a_row3_col20, #T_7144a_row3_col25, #T_7144a_row4_col1, #T_7144a_row4_col6, #T_7144a_row4_col10, #T_7144a_row4_col13, #T_7144a_row4_col19, #T_7144a_row4_col20, #T_7144a_row4_col25, #T_7144a_row5_col1, #T_7144a_row5_col6, #T_7144a_row5_col10, #T_7144a_row5_col13, #T_7144a_row5_col19, #T_7144a_row5_col20, #T_7144a_row5_col25, #T_7144a_row6_col10, #T_7144a_row6_col19, #T_7144a_row6_col20, #T_7144a_row6_col21, #T_7144a_row6_col22, #T_7144a_row6_col25, #T_7144a_row6_col27, #T_7144a_row7_col1, #T_7144a_row7_col19, #T_7144a_row7_col20, #T_7144a_row7_col25, #T_7144a_row7_col27, #T_7144a_row8_col6, #T_7144a_row8_col7, #T_7144a_row8_col13, #T_7144a_row8_col19, #T_7144a_row8_col20, #T_7144a_row8_col25, #T_7144a_row8_col27, #T_7144a_row9_col1, #T_7144a_row9_col15, #T_7144a_row9_col20, #T_7144a_row9_col25, #T_7144a_row10_col1, #T_7144a_row10_col6, #T_7144a_row10_col19, #T_7144a_row10_col20, #T_7144a_row10_col22, #T_7144a_row10_col25, #T_7144a_row11_col7, #T_7144a_row11_col10, #T_7144a_row11_col20, #T_7144a_row12_col6, #T_7144a_row12_col10, #T_7144a_row12_col19, #T_7144a_row12_col20, #T_7144a_row12_col27, #T_7144a_row13_col0, #T_7144a_row13_col19, #T_7144a_row13_col21, #T_7144a_row13_col25, #T_7144a_row14_col1, #T_7144a_row14_col15, #T_7144a_row14_col20, #T_7144a_row14_col25, #T_7144a_row15_col2, #T_7144a_row15_col3, #T_7144a_row15_col4, #T_7144a_row15_col5, #T_7144a_row15_col9, #T_7144a_row15_col10, #T_7144a_row15_col11, #T_7144a_row15_col14, #T_7144a_row15_col16, #T_7144a_row15_col20, #T_7144a_row15_col21, #T_7144a_row15_col22, #T_7144a_row15_col23, #T_7144a_row15_col24, #T_7144a_row15_col27, #T_7144a_row15_col28, #T_7144a_row15_col29, #T_7144a_row16_col7, #T_7144a_row16_col10, #T_7144a_row16_col20, #T_7144a_row16_col25, #T_7144a_row16_col32, #T_7144a_row17_col6, #T_7144a_row17_col7, #T_7144a_row17_col10, #T_7144a_row17_col13, #T_7144a_row17_col19, #T_7144a_row17_col20, #T_7144a_row17_col25, #T_7144a_row17_col27, #T_7144a_row17_col31, #T_7144a_row18_col1, #T_7144a_row18_col6, #T_7144a_row18_col10, #T_7144a_row18_col20, #T_7144a_row18_col27, #T_7144a_row18_col31, #T_7144a_row18_col32, #T_7144a_row19_col6, #T_7144a_row19_col7, #T_7144a_row19_col10, #T_7144a_row19_col13, #T_7144a_row19_col25, #T_7144a_row19_col27, #T_7144a_row20_col6, #T_7144a_row20_col7, #T_7144a_row20_col10, #T_7144a_row20_col25, #T_7144a_row20_col27, #T_7144a_row21_col6, #T_7144a_row21_col7, #T_7144a_row21_col13, #T_7144a_row21_col25, #T_7144a_row22_col0, #T_7144a_row22_col6, #T_7144a_row22_col7, #T_7144a_row22_col10, #T_7144a_row22_col13, #T_7144a_row22_col19, #T_7144a_row22_col25, #T_7144a_row23_col1, #T_7144a_row23_col8, #T_7144a_row23_col12, #T_7144a_row23_col17, #T_7144a_row23_col18, #T_7144a_row23_col20, #T_7144a_row23_col25, #T_7144a_row23_col26, #T_7144a_row23_col30, #T_7144a_row24_col1, #T_7144a_row24_col20, #T_7144a_row24_col25, #T_7144a_row25_col1, #T_7144a_row25_col10, #T_7144a_row25_col13, #T_7144a_row25_col19, #T_7144a_row25_col20, #T_7144a_row26_col7, #T_7144a_row26_col10, #T_7144a_row26_col13, #T_7144a_row26_col19, #T_7144a_row26_col20, #T_7144a_row26_col21, #T_7144a_row26_col22, #T_7144a_row26_col27, #T_7144a_row27_col1, #T_7144a_row27_col6, #T_7144a_row27_col7, #T_7144a_row27_col19, #T_7144a_row27_col20, #T_7144a_row28_col1, #T_7144a_row28_col20, #T_7144a_row28_col25, #T_7144a_row28_col30, #T_7144a_row29_col1, #T_7144a_row29_col6, #T_7144a_row29_col10, #T_7144a_row29_col13, #T_7144a_row29_col19, #T_7144a_row29_col20, #T_7144a_row29_col25, #T_7144a_row30_col4, #T_7144a_row30_col5, #T_7144a_row30_col7, #T_7144a_row30_col10, #T_7144a_row30_col13, #T_7144a_row30_col19, #T_7144a_row30_col20, #T_7144a_row30_c ...
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_7144a_row0_col2, #T_7144a_row0_col3 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_7144a_row0_col4, #T_7144a_row1_col30, #T_7144a_row6_col30, #T_7144a_row22_col2, #T_7144a_row24_col31, #T_7144a_row25_col26, #T_7144a_row26_col17, #T_7144a_row29_col15, #T_7144a_row31_col3 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_7144a_row0_col5, #T_7144a_row1_col24, #T_7144a_row6_col23, #T_7144a_row7_col23, #T_7144a_row8_col30, #T_7144a_row10_col23, #T_7144a_row13_col23, #T_7144a_row18_col2, #T_7144a_row18_col3, #T_7144a_row19_col23, #T_7144a_row20_col24, #T_7144a_row21_col2, #T_7144a_row25_col23 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_7144a_row0_col6, #T_7144a_row0_col7, #T_7144a_row0_col10, #T_7144a_row0_col19, #T_7144a_row1_col6, #T_7144a_row1_col19, #T_7144a_row1_col20, #T_7144a_row1_col21, #T_7144a_row2_col1, #T_7144a_row2_col6, #T_7144a_row2_col19, #T_7144a_row3_col1, #T_7144a_row3_col6, #T_7144a_row3_col13, #T_7144a_row3_col19, #T_7144a_row4_col7, #T_7144a_row4_col27, #T_7144a_row5_col7, #T_7144a_row6_col1, #T_7144a_row6_col7, #T_7144a_row7_col0, #T_7144a_row7_col6, #T_7144a_row7_col10, #T_7144a_row7_col13, #T_7144a_row7_col21, #T_7144a_row7_col22, #T_7144a_row8_col10, #T_7144a_row9_col7, #T_7144a_row9_col10, #T_7144a_row9_col13, #T_7144a_row9_col19, #T_7144a_row10_col0, #T_7144a_row10_col7, #T_7144a_row10_col13, #T_7144a_row10_col27, #T_7144a_row11_col1, #T_7144a_row11_col6, #T_7144a_row11_col13, #T_7144a_row11_col19, #T_7144a_row11_col25, #T_7144a_row12_col7, #T_7144a_row12_col13, #T_7144a_row12_col25, #T_7144a_row13_col1, #T_7144a_row13_col6, #T_7144a_row13_col7, #T_7144a_row13_col10, #T_7144a_row13_col20, #T_7144a_row13_col22, #T_7144a_row13_col27, #T_7144a_row14_col7, #T_7144a_row14_col10, #T_7144a_row14_col13, #T_7144a_row14_col19, #T_7144a_row15_col6, #T_7144a_row15_col7, #T_7144a_row15_col13, #T_7144a_row15_col19, #T_7144a_row15_col25, #T_7144a_row16_col1, #T_7144a_row16_col6, #T_7144a_row16_col13, #T_7144a_row16_col19, #T_7144a_row18_col7, #T_7144a_row18_col13, #T_7144a_row18_col19, #T_7144a_row18_col25, #T_7144a_row19_col1, #T_7144a_row19_col22, #T_7144a_row20_col0, #T_7144a_row20_col1, #T_7144a_row20_col13, #T_7144a_row20_col21, #T_7144a_row21_col1, #T_7144a_row21_col10, #T_7144a_row21_col19, #T_7144a_row21_col20, #T_7144a_row21_col27, #T_7144a_row22_col27, #T_7144a_row23_col6, #T_7144a_row23_col7, #T_7144a_row23_col10, #T_7144a_row23_col13, #T_7144a_row23_col19, #T_7144a_row24_col6, #T_7144a_row24_col7, #T_7144a_row24_col10, #T_7144a_row24_col13, #T_7144a_row24_col19, #T_7144a_row25_col0, #T_7144a_row25_col6, #T_7144a_row25_col7, #T_7144a_row25_col21, #T_7144a_row25_col22, #T_7144a_row25_col27, #T_7144a_row26_col6, #T_7144a_row27_col10, #T_7144a_row27_col13, #T_7144a_row27_col21, #T_7144a_row27_col22, #T_7144a_row27_col25, #T_7144a_row28_col6, #T_7144a_row28_col7, #T_7144a_row28_col10, #T_7144a_row28_col13, #T_7144a_row28_col18, #T_7144a

# %%
type(corr_matrix)
corr_matrix = df.corr()
corr_matrix['payback30'].sort_values(ascending=False)
# Out:
# payback30               1.000000
# payback90               0.830363
# rental30                0.072974
# cnt_loans30             0.067842
# rental90                0.067110
# amnt_loans30            0.060425
# amnt_loans90            0.052142
# label                   0.048336
# cnt_ma_rech30           0.043617
# fr_ma_rech90            0.036817
# daily_decr30            0.026915
# daily_decr90            0.019400
# cnt_da_rech90           0.013430
# maxamnt_loans90         0.013376
# cnt_ma_rech90           0.011943
# aon                     0.001940
# fr_da_rech30            0.001709
# medianmarechprebal30    0.001516
# fr_ma_rech30            0.001455
# cnt_loans90             0.000587
# fr_da_rech90            0.000354
# sumamnt_ma_rech30       0.000112
# last_rech_date_da       0.000077
# cnt_da_rech30          -0.000471
# maxamnt_loans30        -0.001512
# last_rech_date_ma      -0.002233
# medianamnt_loans30     -0.006007
# medianamnt_loans90     -0.013388
# medianamnt_ma_rech30   -0.018398
# sumamnt_ma_rech90      -0.026409
# last_rech_amt_ma       -0.027369
# medianmarechprebal90   -0.031760
# medianamnt_ma_rech90   -0.035640
# Name: payback30, dtype: float64

# %%
 # Let's check the data distribution among all the columns
df.plot(kind='density', subplots=True, layout=(8,8), sharex=False, legend=True, fontsize=1, figsize=(18,12))
plt.show()

# %%
#Transform non-numerical into numerical column.
from sklearn.preprocessing import LabelEncoder

for column in df.columns:
    if df[column].dtype == np.number:
        continue
    df[column] = LabelEncoder().fit_transform(df[column])

# %%
df
# Out:
#         label  msisdn     aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0           0   40191   272.0   3055.050000   3065.150000    220.13    260.13
# 1           1  142291   712.0  12122.000000  12124.750000   3691.26   3691.26
# 2           1   33594   535.0   1398.000000   1398.000000    900.13    900.13
# 3           1  104157   241.0     21.228000     21.228000    159.42    159.42
# 4           1    6910   947.0    150.619333    150.619333   1098.90   1098.90
# ...       ...     ...     ...           ...           ...       ...       ...
# 209588      1   42866   404.0    151.872333    151.872333   1089.19   1089.19
# 209589      1  178248  1075.0     36.936000     36.936000   1728.36   1728.36
# 209590      1   53995  1013.0  11843.111667  11904.350000   5861.83   8893.20
# 209591      1  111388  1732.0  12488.228333  12574.370000    411.83    984.58
# 209592      1  121263  1581.0   4489.362000   4534.820000    483.92    631.20
#
#         last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  \
# 0                     2.0                0.0                14  ...
# 1                    20.0                0.0                38  ...
# 2                     3.0                0.0                14  ...
# 3                    41.0                0.0                10  ...
# 4                     4.0                0.0                23  ...
# ...                   ...                ...               ...  ...
# 209588                1.0                0.0                31  ...
# 209589                4.0                0.0                 6  ...
# 209590                3.0                0.0                14  ...
# 209591                2.0               38.0                 6  ...
# 209592               13.0                0.0                43  ...
#
#         amnt_loans30  maxamnt_loans30  medianamnt_loans30  cnt_loans90  \
# 0                  2              6.0                 0.0          2.0
# 1                  2             12.0                 0.0          1.0
# 2                  1              6.0                 0.0          1.0
# 3                  2              6.0                 0.0          2.0
# 4                  7              6.0                 0.0          7.0
# ...              ...              ...                 ...          ...
# 209588             2              6.0                 0.0          2.0
# 209589             3              6.0                 0.0          3.0
# 209590             7             12.0                 0.0          6.0
# 209591             3             12.0                 0.0          3.0
# 209592             3             12.0                 0.0          2.0
#
#         amnt_loans90  maxamnt_loans90  medianamnt_loans90  payback30  \
# 0                  2                1                 0.0  29.000000
# 1                  2                2                 0.0   0.000000
# 2                  1                1                 0.0   0.000000
# 3                  2                1                 0.0   0.000000
# 4                  7                1                 0.0   2.333333
# ...              ...              ...                 ...        ...
# 209588             2                1                 0.0   1.000000
# 209589             3                1                 0.0   1.000000
# 209590             9                2                 0.0   4.000000
# 209591             4                2                 0.0   0.000000
# 209592             3                2                 0.0   0.000000
#
#         payback90  pdate
# 0       29.000000     49
# 1        0.000000     70
# 2        0.000000     79
# 3        0.000000      5
# 4        2.333333     21
# ...           ...    ...
# 209588   1.000000     16
# 209589   1.000000     11
# 209590   3.833333     58
# 209591  10.500000     54
# 209592   0.000000     36
#
# [209593 rows x 35 columns]

# %% [markdown]
# ## Remove skewness and outliers

# %%
#checking skewness
df.skew().sort_values(ascending=False)
# Out:
# medianmarechprebal90    44.880503
# fr_da_rech90            26.899282
# cnt_da_rech90           23.642903
# cnt_da_rech30           17.818364
# maxamnt_loans30         17.658052
# cnt_loans90             16.594408
# last_rech_date_da       14.814857
# last_rech_date_ma       14.790974
# medianmarechprebal30    14.779875
# fr_da_rech30            14.776430
# fr_ma_rech30            14.772833
# aon                     10.392949
# payback30                8.310695
# payback90                6.899951
# sumamnt_ma_rech30        6.386787
# medianamnt_loans90       4.895720
# medianamnt_loans30       4.551043
# rental30                 4.521929
# rental90                 4.437681
# daily_decr90             4.252565
# daily_decr30             3.946230
# medianamnt_ma_rech90     3.752706
# medianamnt_ma_rech30     3.512324
# amnt_loans90             3.136189
# amnt_loans30             2.955552
# cnt_ma_rech90            2.886544
# cnt_loans30              2.685234
# cnt_ma_rech30            2.684106
# fr_ma_rech90             2.285423
# sumamnt_ma_rech90        1.732703
# maxamnt_loans90          1.678304
# last_rech_amt_ma         1.074621
# pdate                    0.116409
# msisdn                   0.000719
# label                   -2.270254
# dtype: float64

# %%
sk = df.skew()
sk
# Out:
# label                   -2.270254
# msisdn                   0.000719
# aon                     10.392949
# daily_decr30             3.946230
# daily_decr90             4.252565
# rental30                 4.521929
# rental90                 4.437681
# last_rech_date_ma       14.790974
# last_rech_date_da       14.814857
# last_rech_amt_ma         1.074621
# cnt_ma_rech30            2.684106
# fr_ma_rech30            14.772833
# sumamnt_ma_rech30        6.386787
# medianamnt_ma_rech30     3.512324
# medianmarechprebal30    14.779875
# cnt_ma_rech90            2.886544
# fr_ma_rech90             2.285423
# sumamnt_ma_rech90        1.732703
# medianamnt_ma_rech90     3.752706
# medianmarechprebal90    44.880503
# cnt_da_rech30           17.818364
# fr_da_rech30            14.776430
# cnt_da_rech90           23.642903
# fr_da_rech90            26.899282
# cnt_loans30              2.685234
# amnt_loans30             2.955552
# maxamnt_loans30         17.658052
# medianamnt_loans30       4.551043
# cnt_loans90             16.594408
# amnt_loans90             3.136189
# maxamnt_loans90          1.678304
# medianamnt_loans90       4.895720
# payback30                8.310695
# payback90                6.899951
# pdate                    0.116409
# dtype: float64

# %%
sk[np.abs(sk)>0.5]
# Out:
# label                   -2.270254
# aon                     10.392949
# daily_decr30             3.946230
# daily_decr90             4.252565
# rental30                 4.521929
# rental90                 4.437681
# last_rech_date_ma       14.790974
# last_rech_date_da       14.814857
# last_rech_amt_ma         1.074621
# cnt_ma_rech30            2.684106
# fr_ma_rech30            14.772833
# sumamnt_ma_rech30        6.386787
# medianamnt_ma_rech30     3.512324
# medianmarechprebal30    14.779875
# cnt_ma_rech90            2.886544
# fr_ma_rech90             2.285423
# sumamnt_ma_rech90        1.732703
# medianamnt_ma_rech90     3.752706
# medianmarechprebal90    44.880503
# cnt_da_rech30           17.818364
# fr_da_rech30            14.776430
# cnt_da_rech90           23.642903
# fr_da_rech90            26.899282
# cnt_loans30              2.685234
# amnt_loans30             2.955552
# maxamnt_loans30         17.658052
# medianamnt_loans30       4.551043
# cnt_loans90             16.594408
# amnt_loans90             3.136189
# maxamnt_loans90          1.678304
# medianamnt_loans90       4.895720
# payback30                8.310695
# payback90                6.899951
# dtype: float64

# %%
sk[np.abs(sk)<0.25]
# Out:
# msisdn    0.000719
# pdate     0.116409
# dtype: float64

# %%
#checking outliers with boxplot
df.iloc[:,:].boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %%
#Lets quantify
from scipy.stats import zscore
(np.abs(zscore(df))<3).all()
# Out:
# label                    True
# msisdn                   True
# aon                     False
# daily_decr30            False
# daily_decr90            False
# rental30                False
# rental90                False
# last_rech_date_ma       False
# last_rech_date_da       False
# last_rech_amt_ma        False
# cnt_ma_rech30           False
# fr_ma_rech30            False
# sumamnt_ma_rech30       False
# medianamnt_ma_rech30    False
# medianmarechprebal30    False
# cnt_ma_rech90           False
# fr_ma_rech90            False
# sumamnt_ma_rech90       False
# medianamnt_ma_rech90    False
# medianmarechprebal90    False
# cnt_da_rech30           False
# fr_da_rech30            False
# cnt_da_rech90           False
# fr_da_rech90            False
# cnt_loans30             False
# amnt_loans30            False
# maxamnt_loans30         False
# medianamnt_loans30      False
# cnt_loans90             False
# amnt_loans90            False
# maxamnt_loans90         False
# medianamnt_loans90      False
# payback30               False
# payback90               False
# pdate                    True
# dtype: bool

# %%
#display zscore for removing outliers.
from scipy.stats import zscore
z = np.abs(zscore(df))
zscore
z
# Out:
#            label    msisdn       aon  daily_decr30  daily_decr90  rental30  \
# 0       2.647896  0.984213  0.103577      0.252299      0.276346  0.573844
# 1       0.377658  0.915027  0.097764      0.731037      0.553380  0.231788
# 2       0.377658  1.106929  0.100102      0.432011      0.429033  0.416020
# 3       0.377658  0.205668  0.103986      0.581326      0.555125  0.587935
# 4       0.377658  1.603298  0.094660      0.567293      0.543274  0.369886
# ...          ...       ...       ...           ...           ...       ...
# 209588  0.377658  0.934453  0.101833      0.567157      0.543159  0.372140
# 209589  0.377658  1.583891  0.092969      0.579622      0.553686  0.223791
# 209590  0.377658  0.727434  0.093788      0.700790      0.533194  0.735567
# 209591  0.377658  0.340177  0.084289      0.770755      0.594558  0.529352
# 209592  0.377658  0.523869  0.086284      0.096744      0.141746  0.512620
#
#         rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  \
# 0       0.558583           0.069637           0.069550          0.086215  ...
# 1       0.036020           0.069303           0.069550          1.758802  ...
# 2       0.447674           0.069619           0.069550          0.086215  ...
# 3       0.576036           0.068914           0.069550          0.393718  ...
# 4       0.413227           0.069600           0.069550          0.605667  ...
# ...          ...                ...                ...               ...  ...
# 209588  0.414910           0.069656           0.069550          1.220672  ...
# 209589  0.304144           0.069600           0.069550          0.701221  ...
# 209590  0.937500           0.069619           0.069550          0.086215  ...
# 209591  0.433039           0.069637           0.068838          0.701221  ...
# 209592  0.494278           0.069433           0.069550          2.143181  ...
#
#         amnt_loans30  maxamnt_loans30  medianamnt_loans30  cnt_loans90  \
# 0           0.342631         0.063284            0.247794     0.073493
# 1           0.342631         0.061871            0.247794     0.077941
# 2           0.688065         0.063284            0.247794     0.077941
# 3           0.342631         0.063284            0.247794     0.073493
# 4           1.384540         0.063284            0.247794     0.051250
# ...              ...              ...                 ...          ...
# 209588      0.342631         0.063284            0.247794     0.073493
# 209589      0.002803         0.063284            0.247794     0.069044
# 209590      1.384540         0.061871            0.247794     0.055699
# 209591      0.002803         0.061871            0.247794     0.069044
# 209592      0.002803         0.061871            0.247794     0.073493
#
#         amnt_loans90  maxamnt_loans90  medianamnt_loans90  payback30  \
# 0           0.440104         0.334212            0.229594   2.904700
# 1           0.440104         2.517690            0.229594   0.385630
# 2           0.666872         0.334212            0.229594   0.385630
# 3           0.440104         0.334212            0.229594   0.385630
# 4           0.693735         0.334212            0.229594   0.120890
# ...              ...              ...                 ...        ...
# 209588      0.440104         0.334212            0.229594   0.272170
# 209589      0.213337         0.334212            0.229594   0.272170
# 209590      1.147270         2.517690            0.229594   0.068209
# 209591      0.013431         2.517690            0.229594   0.385630
# 209592      0.213337         2.517690            0.229594   0.385630
#
#         payback90     pdate
# 0        2.394093  0.522400
# 1        0.419233  1.477398
# 2        0.419233  1.886683
# 3        0.419233  1.478548
# 4        0.192873  0.750931
# ...           ...       ...
# 209588   0.322221  0.978311
# 209589   0.322221  1.205691
# 209590   0.047356  0.931685
# 209591   0.599385  0.749780
# 209592   0.419233  0.068789
#
# [209593 rows x 35 columns]

# %%
#threshold for zscore values ----> above 3 are considerd outliers.
threshold = 3 
print(np.where(z>3))
# Out:
# (array([    21,     22,     22, ..., 209586, 209587, 209587], dtype=int64), array([16, 16, 33, ..., 29, 27, 31], dtype=int64))

# %%
#removing outliers.
df_new = df[(z<3).all(axis=1)]

# %%
#display old dataset rows and columns.
df.shape
# Out:
# (209593, 35)

# %%
#display new dataset rows and columns without outliers.
df_new.shape
# Out:
# (162025, 35)

# %%
#assign new dataset into old numeric dataset.
df = df_new
df.shape
# Out:
# (162025, 35)

# %%
#checking outliers with boxplot
df.iloc[:,:].boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %% [markdown]
# ## Data Preprocessing

# %%
#apply encoding technique on string or object variable.
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
list1 = ['payback30']
for val in list1:
    df[val] = le.fit_transform(df[val].astype(str))
df
# Out:
#         label  msisdn     aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0           0   40191   272.0   3055.050000   3065.150000    220.13    260.13
# 1           1  142291   712.0  12122.000000  12124.750000   3691.26   3691.26
# 2           1   33594   535.0   1398.000000   1398.000000    900.13    900.13
# 3           1  104157   241.0     21.228000     21.228000    159.42    159.42
# 4           1    6910   947.0    150.619333    150.619333   1098.90   1098.90
# ...       ...     ...     ...           ...           ...       ...       ...
# 209588      1   42866   404.0    151.872333    151.872333   1089.19   1089.19
# 209589      1  178248  1075.0     36.936000     36.936000   1728.36   1728.36
# 209590      1   53995  1013.0  11843.111667  11904.350000   5861.83   8893.20
# 209591      1  111388  1732.0  12488.228333  12574.370000    411.83    984.58
# 209592      1  121263  1581.0   4489.362000   4534.820000    483.92    631.20
#
#         last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  \
# 0                     2.0                0.0                14  ...
# 1                    20.0                0.0                38  ...
# 2                     3.0                0.0                14  ...
# 3                    41.0                0.0                10  ...
# 4                     4.0                0.0                23  ...
# ...                   ...                ...               ...  ...
# 209588                1.0                0.0                31  ...
# 209589                4.0                0.0                 6  ...
# 209590                3.0                0.0                14  ...
# 209591                2.0               38.0                 6  ...
# 209592               13.0                0.0                43  ...
#
#         amnt_loans30  maxamnt_loans30  medianamnt_loans30  cnt_loans90  \
# 0                  2              6.0                 0.0          2.0
# 1                  2             12.0                 0.0          1.0
# 2                  1              6.0                 0.0          1.0
# 3                  2              6.0                 0.0          2.0
# 4                  7              6.0                 0.0          7.0
# ...              ...              ...                 ...          ...
# 209588             2              6.0                 0.0          2.0
# 209589             3              6.0                 0.0          3.0
# 209590             7             12.0                 0.0          6.0
# 209591             3             12.0                 0.0          3.0
# 209592             3             12.0                 0.0          2.0
#
#         amnt_loans90  maxamnt_loans90  medianamnt_loans90  payback30  \
# 0                  2                1                 0.0        318
# 1                  2                2                 0.0          0
# 2                  1                1                 0.0          0
# 3                  2                1                 0.0          0
# 4                  7                1                 0.0        200
# ...              ...              ...                 ...        ...
# 209588             2                1                 0.0          1
# 209589             3                1                 0.0          1
# 209590             9                2                 0.0        368
# 209591             4                2                 0.0          0
# 209592             3                2                 0.0          0
#
#         payback90  pdate
# 0       29.000000     49
# 1        0.000000     70
# 2        0.000000     79
# 3        0.000000      5
# 4        2.333333     21
# ...           ...    ...
# 209588   1.000000     16
# 209589   1.000000     11
# 209590   3.833333     58
# 209591  10.500000     54
# 209592   0.000000     36
#
# [162025 rows x 35 columns]

# %%
#Splitting the independent and target variable in x and y before removing the skewness
x = df.drop("payback30",axis=1)
print(x)
# Out:
#         label  msisdn     aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0           0   40191   272.0   3055.050000   3065.150000    220.13    260.13
# 1           1  142291   712.0  12122.000000  12124.750000   3691.26   3691.26
# 2           1   33594   535.0   1398.000000   1398.000000    900.13    900.13
# 3           1  104157   241.0     21.228000     21.228000    159.42    159.42
# 4           1    6910   947.0    150.619333    150.619333   1098.90   1098.90
# ...       ...     ...     ...           ...           ...       ...       ...
# 209588      1   42866   404.0    151.872333    151.872333   1089.19   1089.19
# 209589      1  178248  1075.0     36.936000     36.936000   1728.36   1728.36
# 209590      1   53995  1013.0  11843.111667  11904.350000   5861.83   8893.20
# 209591      1  111388  1732.0  12488.228333  12574.370000    411.83    984.58
# 209592      1  121263  1581.0   4489.362000   4534.820000    483.92    631.20
#
#         last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  \
# 0                     2.0                0.0                14  ...
# 1                    20.0                0.0                38  ...
# 2                     3.0                0.0                14  ...
# 3                    41.0                0.0                10  ...
# 4                     4.0                0.0                23  ...
# ...                   ...                ...               ...  ...
# 209588                1.0                0.0                31  ...
# 209589                4.0                0.0                 6  ...
# 209590                3.0                0.0                14  ...
# 209591                2.0               38.0                 6  ...
# 209592               13.0                0.0                43  ...
#
#         cnt_loans30  amnt_loans30  maxamnt_loans30  medianamnt_loans30  \
# 0                 2             2              6.0                 0.0
# 1                 1             2             12.0                 0.0
# 2                 1             1              6.0                 0.0
# 3                 2             2              6.0                 0.0
# 4                 7             7              6.0                 0.0
# ...             ...           ...              ...                 ...
# 209588            2             2              6.0                 0.0
# 209589            3             3              6.0                 0.0
# 209590            4             7             12.0                 0.0
# 209591            2             3             12.0                 0.0
# 209592            2             3             12.0                 0.0
#
#         cnt_loans90  amnt_loans90  maxamnt_loans90  medianamnt_loans90  \
# 0               2.0             2                1                 0.0
# 1               1.0             2                2                 0.0
# 2               1.0             1                1                 0.0
# 3               2.0             2                1                 0.0
# 4               7.0             7                1                 0.0
# ...             ...           ...              ...                 ...
# 209588          2.0             2                1                 0.0
# 209589          3.0             3                1                 0.0
# 209590          6.0             9                2                 0.0
# 209591          3.0             4                2                 0.0
# 209592          2.0             3                2                 0.0
#
#         payback90  pdate
# 0       29.000000     49
# 1        0.000000     70
# 2        0.000000     79
# 3        0.000000      5
# 4        2.333333     21
# ...           ...    ...
# 209588   1.000000     16
# 209589   1.000000     11
# 209590   3.833333     58
# 209591  10.500000     54
# 209592   0.000000     36
#
# [162025 rows x 34 columns]

# %%
y = df['payback30'].apply(lambda y_value: 1 if y_value >=7 else 0)
print(y)
# Out:
# 0         1
# 1         0
# 2         0
# 3         0
# 4         1
#          ..
# 209588    0
# 209589    0
# 209590    1
# 209591    0
# 209592    0
# Name: payback30, Length: 162025, dtype: int64

# %%
print(x.shape, y.shape)
# Out:
# (162025, 34) (162025,)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

# %%
maxAccu = 0
maxRS = 0

for i in range(1,100):
    x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = .20, random_state = i)
    rfc = RandomForestClassifier()
    rfc.fit(x_train,y_train)
    pred = rfc.predict(x_test)
    acc = accuracy_score(y_test, pred)
    print('accuracy',acc,'random_state',i)
    
    if acc > maxAccu:
        maxAccu = acc
        maxRS = i
# Out:
# accuracy 0.9814226199660546 random_state 1
# accuracy 0.9825335596358586 random_state 2
# accuracy 0.9829964511649437 random_state 3
# accuracy 0.9833976238234841 random_state 4
# accuracy 0.9808054312606079 random_state 5
# accuracy 0.98228668415368 random_state 6
# accuracy 0.982934732294399 random_state 7
# accuracy 0.981916370930412 random_state 8
# accuracy 0.9834593426940287 random_state 9
# accuracy 0.9823484030242247 random_state 10
# accuracy 0.9827804351180374 random_state 11
# accuracy 0.982379262459497 random_state 12
# accuracy 0.9831507483413053 random_state 13
# accuracy 0.9827187162474926 random_state 14
# accuracy 0.9818546520598673 random_state 15
# accuracy 0.9813917605307823 random_state 16
# accuracy 0.9819472303656843 random_state 17
# accuracy 0.983119888906033 random_state 18
# accuracy 0.9821323869773183 random_state 19
# accuracy 0.9817003548835056 random_state 20
# accuracy 0.9821323869773183 random_state 21
# accuracy 0.9830581700354883 random_state 22
# accuracy 0.9833050455176671 random_state 23
# accuracy 0.983582780435118 random_state 24
# accuracy 0.9811448850486036 random_state 25
# accuracy 0.9821941058478629 random_state 26
# accuracy 0.9822249652831353 random_state 27
# accuracy 0.982379262459497 random_state 28
# accuracy 0.9837062181762074 random_state 29
# accuracy 0.9824409813300417 random_state 30
# accuracy 0.9821323869773183 random_state 31
# accuracy 0.9826878568122204 random_state 32
# accuracy 0.981546057707144 random_state 33
# accuracy 0.9819780898009567 random_state 34
# accuracy 0.9827187162474926 random_state 35
# accuracy 0.9835519209998457 random_state 36
# accuracy 0.9829038728591267 random_state 37
# accuracy 0.9823484030242247 random_state 38
# accuracy 0.9825027002005863 random_state 39
# accuracy 0.9818855114951396 random_state 40
# accuracy 0.982842153988582 random_state 41
# accuracy 0.982934732294399 random_state 42
# accuracy 0.9829038728591267 random_state 43
# accuracy 0.9825027002005863 random_state 44
# accuracy 0.982934732294399 random_state 45
# accuracy 0.9820398086715013 random_state 46
# accuracy 0.981823792624595 random_state 47
# accuracy 0.9824409813300417 random_state 48
# accuracy 0.9821323869773183 random_state 49
# accuracy 0.98228668415368 random_state 50
# accuracy 0.9827804351180374 random_state 51
# accuracy 0.9834593426940287 random_state 52
# accuracy 0.9819780898009567 random_state 53
# accuracy 0.9819472303656843 random_state 54
# accuracy 0.9812374633544206 random_state 55
# accuracy 0.9832433266471223 random_state 56
# accuracy 0.9822249652831353 random_state 57
# accuracy 0.9839839530936584 random_state 58
# accuracy 0.9817929331893226 random_state 59
# accuracy 0.9834593426940287 random_state 60
# accuracy 0.9816694954482333 random_state 61
# accuracy 0.9825335596358586 random_state 62
# accuracy 0.9815769171424162 random_state 63
# accuracy 0.9820706681067737 random_state 64
# accuracy 0.9836136398703904 random_state 65
# accuracy 0.9831507483413053 random_state 66
# accuracy 0.9821323869773183 random_state 67
# accuracy 0.9830581700354883 random_state 68
# accuracy 0.9827187162474926 random_state 69
# accuracy 0.9817620737540503 random_state 70
# accuracy 0.981916370930412 random_state 71
# accuracy 0.982564419071131 random_state 72
# accuracy 0.9820706681067737 random_state 73
# accuracy 0.9812066039191483 random_state 74
# accuracy 0.9813300416602376 random_state 75
# accuracy 0.9821323869773183 random_state 76
# accuracy 0.9810523067427867 random_state 77
# accuracy 0.982656997376948 random_state 78
# accuracy 0.9832124672118501 random_state 79
# accuracy 0.9821941058478629 random_state 80
# accuracy 0.9834593426940287 random_state 81
# accuracy 0.9831507483413053 random_state 82
# accuracy 0.983119888906033 random_state 83
# accuracy 0.981823792624595 random_state 84
# accuracy 0.9824101218947693 random_state 85
# accuracy 0.982842153988582 random_state 86
# accuracy 0.983860515352569 random_state 87
# accuracy 0.982749575682765 random_state 88
# accuracy 0.9828730134238544 random_state 89
# accuracy 0.9831507483413053 random_state 90
# accuracy 0.9825952785064034 random_state 91
# accuracy 0.98136090109551 random_state 92
# accuracy 0.9828730134238544 random_state 93
# accuracy 0.9822558247184077 random_state 94
# accuracy 0.9826878568122204 random_state 95
# accuracy 0.9818546520598673 random_state 96
# accuracy 0.983582780435118 random_state 97
# accuracy 0.983027310600216 random_state 98
# accuracy 0.982934732294399 random_state 99

# %%
print("Best accuracy is ",maxAccu,"On Random_state ",maxRS)
# Out:
# Best accuracy is  0.9844468446227435 On Random_state  58

# %%
maxAccu = 0
maxRS = 0

for i in range(1,100):
    x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = .20, random_state = i)
    lr = LogisticRegression()
    lr.fit(x_train,y_train)
    pred = lr.predict(x_test)
    acc = accuracy_score(y_test, pred)
    print('accuracy',acc,'random_state',i)
    
    if acc > maxAccu:
        maxAccu = acc
        maxRS = i
# Out:
# accuracy 0.7705292393149206 random_state 1
# accuracy 0.7709612714087333 random_state 2
# accuracy 0.7743249498534177 random_state 3
# accuracy 0.7742940904181453 random_state 4
# accuracy 0.7724116648665329 random_state 5
# accuracy 0.7704366610091036 random_state 6
# accuracy 0.7734917451010647 random_state 7
# accuracy 0.7746026847708687 random_state 8
# accuracy 0.7698194723036569 random_state 9
# accuracy 0.7727511186545286 random_state 10
# accuracy 0.7671964203055084 random_state 11
# accuracy 0.7673815769171424 random_state 12
# accuracy 0.7683073599753124 random_state 13
# accuracy 0.7715167412436352 random_state 14
# accuracy 0.7704366610091036 random_state 15
# accuracy 0.765962042894615 random_state 16
# accuracy 0.773152291313069 random_state 17
# accuracy 0.7664866532942447 random_state 18
# accuracy 0.7694182996451165 random_state 19
# accuracy 0.7665483721647894 random_state 20
# accuracy 0.7715167412436352 random_state 21
# accuracy 0.7723190865607159 random_state 22
# accuracy 0.7699737694800185 random_state 23
# accuracy 0.7724116648665329 random_state 24
# accuracy 0.7687085326338527 random_state 25
# accuracy 0.7718870544669033 random_state 26
# accuracy 0.7661780589415214 random_state 27
# accuracy 0.7726276809134393 random_state 28
# accuracy 0.7677827495756827 random_state 29
# accuracy 0.7707761147970992 random_state 30
# accuracy 0.764943681530628 random_state 31
# accuracy 0.7713933035025459 random_state 32
# accuracy 0.7673815769171424 random_state 33
# accuracy 0.7710847091498225 random_state 34
# accuracy 0.767072982564419 random_state 35
# accuracy 0.7735534639716093 random_state 36
# accuracy 0.772967134701435 random_state 37
# accuracy 0.7707143959265546 random_state 38
# accuracy 0.7707452553618269 random_state 39
# accuracy 0.7701280666563802 random_state 40
# accuracy 0.7716093195494522 random_state 41
# accuracy 0.764665946613177 random_state 42
# accuracy 0.7683999382811294 random_state 43
# accuracy 0.7688011109396699 random_state 44
# accuracy 0.7747878413825027 random_state 45
# accuracy 0.7689245486807591 random_state 46
# accuracy 0.7714241629378182 random_state 47
# accuracy 0.7765776886282981 random_state 48
# accuracy 0.7724733837370776 random_state 49
# accuracy 0.765776886282981 random_state 50
# accuracy 0.7658077457182534 random_state 51
# accuracy 0.7720413516432649 random_state 52
# accuracy 0.7697268939978399 random_state 53
# accuracy 0.7688011109396699 random_state 54
# accuracy 0.7714858818083629 random_state 55
# accuracy 0.7697886128683845 random_state 56
# accuracy 0.7707452553618269 random_state 57
# accuracy 0.773892917759605 random_state 58
# accuracy 0.7730288535719796 random_state 59
# accuracy 0.7708378336676439 random_state 60
# accuracy 0.7722573676901713 random_state 61
# accuracy 0.764480790001543 random_state 62
# accuracy 0.7664866532942447 random_state 63
# accuracy 0.7756210461348557 random_state 64
# accuracy 0.7695417373862058 random_state 65
# accuracy 0.7616108625212159 random_state 66
# accuracy 0.7724733837370776 random_state 67
# accuracy 0.7718253355963586 random_state 68
# accuracy 0.7697268939978399 random_state 69
# accuracy 0.7679679061873168 random_state 70
# accuracy 0.7703132232680142 random_state 71
# accuracy 0.7670112636938744 random_state 72
# accuracy 0.7726585403487116 random_state 73
# accuracy 0.7710847091498225 random_state 74
# accuracy 0.7756210461348557 random_state 75
# accuracy 0.7715167412436352 random_state 76
# accuracy 0.772689399783984 random_state 77
# accuracy 0.7685233760222188 random_state 78
# accuracy 0.7726585403487116 random_state 79
# accuracy 0.7733065884894307 random_state 80
# accuracy 0.7711464280203673 random_state 81
# accuracy 0.7739237771948774 random_state 82
# accuracy 0.7740163555006944 random_state 83
# accuracy 0.7671964203055084 random_state 84
# accuracy 0.767072982564419 random_state 85
# accuracy 0.7726276809134393 random_state 86
# accuracy 0.7732757290541583 random_state 87
# accuracy 0.7699120506094739 random_state 88
# accuracy 0.7685850948927635 random_state 89
# accuracy 0.7750655762999538 random_state 90
# accuracy 0.7733991667952477 random_state 91
# accuracy 0.7699429100447461 random_state 92
# accuracy 0.7707452553618269 random_state 93
# accuracy 0.7724425243018053 random_state 94
# accuracy 0.7733065884894307 random_state 95
# accuracy 0.7700046289152909 random_state 96
# accuracy 0.7683382194105848 random_state 97
# accuracy 0.7700663477858355 random_state 98
# accuracy 0.7688319703749421 random_state 99

# %%
print("Best accuracy is ",maxAccu,"On Random_state ",maxRS)
# Out:
# Best accuracy is  0.7765776886282981 On Random_state  48

# %%
maxAccu = 0
maxRS = 0

for i in range(1,100):
    x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = .20, random_state = i)
    dtc = DecisionTreeClassifier()
    dtc.fit(x_train,y_train)
    pred = dtc.predict(x_test)
    acc = accuracy_score(y_test, pred)
    print('accuracy',acc,'random_state',i)
    
    if acc > maxAccu:
        maxAccu = acc
        maxRS = i
# Out:
# accuracy 0.9754358895232217 random_state 1
# accuracy 0.9764542508872087 random_state 2
# accuracy 0.9755284678290387 random_state 3
# accuracy 0.9757753433112174 random_state 4
# accuracy 0.9758987810523068 random_state 5
# accuracy 0.9758679216170344 random_state 6
# accuracy 0.9747878413825027 random_state 7
# accuracy 0.9760530782286684 random_state 8
# accuracy 0.9758987810523068 random_state 9
# accuracy 0.9744792470297794 random_state 10
# accuracy 0.975651905570128 random_state 11
# accuracy 0.9753741706526771 random_state 12
# accuracy 0.9752198734763153 random_state 13
# accuracy 0.9756210461348558 random_state 14
# accuracy 0.9750038574294091 random_state 15
# accuracy 0.9741397932417837 random_state 16
# accuracy 0.974633544206141 random_state 17
# accuracy 0.9758679216170344 random_state 18
# accuracy 0.9759296404875791 random_state 19
# accuracy 0.9747878413825027 random_state 20
# accuracy 0.9758062027464898 random_state 21
# accuracy 0.9759296404875791 random_state 22
# accuracy 0.9766394074988428 random_state 23
# accuracy 0.9750655762999537 random_state 24
# accuracy 0.9737386205832433 random_state 25
# accuracy 0.974078074371239 random_state 26
# accuracy 0.9763308131461195 random_state 27
# accuracy 0.9753124517821324 random_state 28
# accuracy 0.9771022990279278 random_state 29
# accuracy 0.9738311988890603 random_state 30
# accuracy 0.9751890140410431 random_state 31
# accuracy 0.9745101064650517 random_state 32
# accuracy 0.9753433112174047 random_state 33
# accuracy 0.9750347168646814 random_state 34
# accuracy 0.9757753433112174 random_state 35
# accuracy 0.9764542508872087 random_state 36
# accuracy 0.9758062027464898 random_state 37
# accuracy 0.9746644036414134 random_state 38
# accuracy 0.9747878413825027 random_state 39
# accuracy 0.9754976083937664 random_state 40
# accuracy 0.9759296404875791 random_state 41
# accuracy 0.9754667489584941 random_state 42
# accuracy 0.9758062027464898 random_state 43
# accuracy 0.9759913593581238 random_state 44
# accuracy 0.9764851103224811 random_state 45
# accuracy 0.9753433112174047 random_state 46
# accuracy 0.974911279123592 random_state 47
# accuracy 0.9741089338065113 random_state 48
# accuracy 0.9767011263693874 random_state 49
# accuracy 0.9750347168646814 random_state 50
# accuracy 0.9747569819472304 random_state 51
# accuracy 0.9750347168646814 random_state 52
# accuracy 0.9759296404875791 random_state 53
# accuracy 0.9744175281592347 random_state 54
# accuracy 0.9754976083937664 random_state 55
# accuracy 0.974818700817775 random_state 56
# accuracy 0.9763925320166641 random_state 57
# accuracy 0.9751581546057707 random_state 58
# accuracy 0.9760530782286684 random_state 59
# accuracy 0.9778120660391915 random_state 60
# accuracy 0.9746644036414134 random_state 61
# accuracy 0.975744483875945 random_state 62
# accuracy 0.9742015121123283 random_state 63
# accuracy 0.9751272951704983 random_state 64
# accuracy 0.9765776886282981 random_state 65
# accuracy 0.9766394074988428 random_state 66
# accuracy 0.9751272951704983 random_state 67
# accuracy 0.9754050300879494 random_state 68
# accuracy 0.9759296404875791 random_state 69
# accuracy 0.9751581546057707 random_state 70
# accuracy 0.9742323715476007 random_state 71
# accuracy 0.974911279123592 random_state 72
# accuracy 0.9747878413825027 random_state 73
# accuracy 0.9729054158308903 random_state 74
# accuracy 0.9736769017126986 random_state 75
# accuracy 0.9753124517821324 random_state 76
# accuracy 0.9750964357352261 random_state 77
# accuracy 0.9754050300879494 random_state 78
# accuracy 0.975837062181762 random_state 79
# accuracy 0.9766702669341151 random_state 80
# accuracy 0.9737386205832433 random_state 81
# accuracy 0.9754358895232217 random_state 82
# accuracy 0.9752815923468601 random_state 83
# accuracy 0.9755901866995834 random_state 84
# accuracy 0.9754358895232217 random_state 85
# accuracy 0.975651905570128 random_state 86
# accuracy 0.9754976083937664 random_state 87
# accuracy 0.9757753433112174 random_state 88
# accuracy 0.9752198734763153 random_state 89
# accuracy 0.9748495602530474 random_state 90
# accuracy 0.9748495602530474 random_state 91
# accuracy 0.973337447924703 random_state 92
# accuracy 0.9750964357352261 random_state 93
# accuracy 0.9754050300879494 random_state 94
# accuracy 0.9762690942755747 random_state 95
# accuracy 0.9737694800185157 random_state 96
# accuracy 0.9767011263693874 random_state 97
# accuracy 0.9751272951704983 random_state 98
# accuracy 0.9747569819472304 random_state 99

# %%
print("Best accuracy is ",maxAccu,"On Random_state ",maxRS)
# Out:
# Best accuracy is  0.9778120660391915 On Random_state  60

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=.20,random_state = 58)

# %%
x_train
# Out:
#         label  msisdn     aon  daily_decr30  daily_decr90  rental30  rental90  \
# 190600      1   15031   433.0     55.284000     55.284000   1301.76   1301.76
# 127590      1   41858  1276.0   9320.604000   9357.720000   1806.20   2237.39
# 162895      1   36907   211.0     40.880000     40.880000    670.56    670.56
# 157586      0  117791   737.0   2663.896000   2666.040000   2039.55   2708.43
# 192273      1  170829  1092.0   8905.930000   8936.450000    741.96    829.96
# ...       ...     ...     ...           ...           ...       ...       ...
# 33081       1  102200  1760.0   3680.000000   4672.850000   3852.30   4444.19
# 162607      1  144273   118.0   4148.554000   4215.180000   1387.91   1978.64
# 54652       0  164931  1725.0     -5.000000     -5.000000   2478.30   2478.30
# 45124       0  138819   180.0     -0.058667     -0.058667   2142.80   2142.80
# 83790       1    7371   129.0   6771.610000   6825.220000   2709.92   3154.67
#
#         last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  \
# 190600                3.0                0.0                 6  ...
# 127590                4.0                0.0                23  ...
# 162895                1.0                0.0                21  ...
# 157586                6.0                0.0                14  ...
# 192273                3.0                0.0                14  ...
# ...                   ...                ...               ...  ...
# 33081                21.0                0.0                14  ...
# 162607                2.0                0.0                14  ...
# 54652                 0.0                0.0                 0  ...
# 45124                 0.0                0.0                 0  ...
# 83790                 4.0                0.0                14  ...
#
#         cnt_loans30  amnt_loans30  maxamnt_loans30  medianamnt_loans30  \
# 190600            3             3              6.0                 0.0
# 127590            5             5              6.0                 0.0
# 162895            2             2              6.0                 0.0
# 157586            2             3             12.0                 0.0
# 192273            6             6              6.0                 0.0
# ...             ...           ...              ...                 ...
# 33081             1             2             12.0                 0.0
# 162607            2             2              6.0                 0.0
# 54652             1             1              6.0                 0.0
# 45124             1             1              6.0                 0.0
# 83790             3             4             12.0                 0.0
#
#         cnt_loans90  amnt_loans90  maxamnt_loans90  medianamnt_loans90  \
# 190600          3.0             3                1                 0.0
# 127590          7.0             7                1                 0.0
# 162895          2.0             2                1                 0.0
# 157586          2.0             3                2                 0.0
# 192273          7.0             7                1                 0.0
# ...             ...           ...              ...                 ...
# 33081           1.0             2                2                 0.0
# 162607          2.0             2                1                 0.0
# 54652           1.0             1                1                 0.0
# 45124           1.0             1                1                 0.0
# 83790           3.0             4                2                 0.0
#
#         payback90  pdate
# 190600  15.000000     11
# 127590   2.333333     38
# 162895   2.000000     15
# 157586  18.000000     37
# 192273   2.166667     37
# ...           ...    ...
# 33081    0.000000     73
# 162607   0.000000     50
# 54652    0.000000     29
# 45124    0.000000     10
# 83790    3.000000     44
#
# [129620 rows x 34 columns]

# %%
y_train
# Out:
# 190600    1
# 127590    1
# 162895    1
# 157586    1
# 192273    1
#          ..
# 33081     0
# 162607    0
# 54652     0
# 45124     0
# 83790     1
# Name: payback30, Length: 129620, dtype: int64

# %%
y_test
# Out:
# 114683    0
# 31301     1
# 204345    1
# 158409    0
# 52324     1
#          ..
# 76508     1
# 150481    0
# 57914     0
# 111071    1
# 119424    0
# Name: payback30, Length: 32405, dtype: int64

# %%
print(x.shape, x_train.shape, x_test.shape)
# Out:
# (162025, 34) (129620, 34) (32405, 34)

# %%
print(y.shape, y_train.shape, y_test.shape)
# Out:
# (162025,) (129620,) (32405,)

# %%
#Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier()
rfc.fit(x_train,y_train)
pred = rfc.predict(x_test)
print('accuracy',accuracy_score(y_test, pred)*100)
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# accuracy 98.17620737540503
# [[17013   404]
#  [  187 14801]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98     17417
#            1       0.97      0.99      0.98     14988
#
#     accuracy                           0.98     32405
#    macro avg       0.98      0.98      0.98     32405
# weighted avg       0.98      0.98      0.98     32405

# %%
#Decision Tree Classifier
from sklearn.tree import DecisionTreeClassifier

dtc = DecisionTreeClassifier()
dtc.fit(x_train,y_train)
pred = dtc.predict(x_test)
print('accuracy',accuracy_score(y_test, pred)*100)
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# accuracy 97.51890140410431
# [[17009   408]
#  [  396 14592]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98     17417
#            1       0.97      0.97      0.97     14988
#
#     accuracy                           0.98     32405
#    macro avg       0.98      0.98      0.98     32405
# weighted avg       0.98      0.98      0.98     32405

# %%
# SVC
from sklearn.svm import SVC

svc = SVC()
svc.fit(x_train,y_train)
pred = svc.predict(x_test)
print('accuracy',accuracy_score(y_test, pred)*100)
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# accuracy 77.79663632155531
# [[14083  3334]
#  [ 3861 11127]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.81      0.80     17417
#            1       0.77      0.74      0.76     14988
#
#     accuracy                           0.78     32405
#    macro avg       0.78      0.78      0.78     32405
# weighted avg       0.78      0.78      0.78     32405

# %%
#Logistic Regression
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()
lr.fit(x_train,y_train)
pred = lr.predict(x_test)
print('accuracy',accuracy_score(y_test, pred)*100)
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# accuracy 77.3152291313069
# [[14334  3083]
#  [ 4268 10720]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.82      0.80     17417
#            1       0.78      0.72      0.74     14988
#
#     accuracy                           0.77     32405
#    macro avg       0.77      0.77      0.77     32405
# weighted avg       0.77      0.77      0.77     32405

# %%
#XGBClassifier
from xgboost import XGBClassifier
xc = XGBClassifier()
xc.fit(x_train,y_train)
pred = xc.predict(x_test)
print('accuracy',accuracy_score(y_test, pred)*100)
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# accuracy 98.50023144576454
# [[17104   313]
#  [  173 14815]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99     17417
#            1       0.98      0.99      0.98     14988
#
#     accuracy                           0.99     32405
#    macro avg       0.98      0.99      0.98     32405
# weighted avg       0.99      0.99      0.99     32405

# %%
#Cross Validation
from sklearn.model_selection import cross_val_score

scr = cross_val_score(rfc, x, y, cv=5)
print('cross validation score of random forest classifier model :',scr.mean())
# Out:
# cross validation score of random forest classifier model : 0.9823977781206604

# %%
scr2 = cross_val_score(lr, x, y, cv=5)
print('cross validation score of logistic regression model :',scr2.mean())
# Out:
# cross validation score of logistic regression model : 0.7694553309674432

# %%
scr3 = cross_val_score(dtc, x, y, cv=5)
print('cross validation score of decision tree classifier model :',scr3.mean())
# Out:
# cross validation score of decision tree classifier model : 0.9756951087795093

# %%
#Hyper parameter tuning
from sklearn.model_selection import GridSearchCV

parameters = {'max_features': ['auto','sqrt','log2'],
              'max_depth': [4,5,6,7,8],
              'criterion':['gini','entropy']}

# %%
GCV = GridSearchCV(RandomForestClassifier(),parameters,cv=5,scoring='accuracy')
GCV.fit(x_train,y_train)
GCV.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'auto'}

# %%
type(GCV)
# Out:
# sklearn.model_selection._search.GridSearchCV

# %%
GCV.best_estimator_
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=8)

# %%
GCV_pred = GCV.best_estimator_.predict(x_test)
accuracy_score(y_test,GCV_pred)
# Out:
# 0.9757753433112174

# %%
from sklearn.metrics import plot_roc_curve
plot_roc_curve(GCV.best_estimator_,x_test,y_test)
plt.title("ROC AUC Plot")
plt.show()

# %%
import pickle
filename = 'sales.pkl'
pickle.dump( rfc,open(filename,'wb'))
